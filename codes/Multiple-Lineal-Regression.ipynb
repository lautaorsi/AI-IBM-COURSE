# %% [markdown]
# # Regresion Lineal Multiple
#
# Para este codigo vamos a necesitar nuevamente las dependencias Numpy, Matplotlib, Pandas y Scikit-learn. Por otro lado, vamos a trabajar nuevamente con el modelo de consumo de combustible visto en la [Regresion Lineal Simlpe](./Logistic-Regression.ipynb)

# %%
# !pip install numpy==2.2.0
# !pip install pandas==2.2.3
# !pip install scikit-learn==1.6.0
# !pip install matplotlib==3.9.3
# Out:
# Requirement already satisfied: numpy==2.2.0 in /home/lo/anaconda3/lib/python3.13/site-packages (2.2.0)
# Requirement already satisfied: pandas==2.2.3 in /home/lo/anaconda3/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/lo/anaconda3/lib/python3.13/site-packages (from pandas==2.2.3) (2.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/lo/anaconda3/lib/python3.13/site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/lo/anaconda3/lib/python3.13/site-packages (from pandas==2.2.3) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/lo/anaconda3/lib/python3.13/site-packages (from pandas==2.2.3) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/lo/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
# Requirement already satisfied: scikit-learn==1.6.0 in /home/lo/anaconda3/lib/python3.13/site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/lo/anaconda3/lib/python3.13/site-packages (from scikit-learn==1.6.0) (2.2.0)
# Requirement already satisfied: scipy>=1.6.0 in /home/lo/anaconda3/lib/python3.13/site-packages (from scikit-learn==1.6.0) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /home/lo/anaconda3/lib/python3.13/site-packages (from scikit-learn==1.6.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/lo/anaconda3/lib/python3.13/site-packages (from scikit-learn==1.6.0) (3.5.0)
# Requirement already satisfied: matplotlib==3.9.3 in /home/lo/anaconda3/lib/python3.13/site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/lo/anaconda3/lib/python3.13/site-packages (from matplotlib==3.9.3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/lo/anaconda3/lib/python3.13/site-packages (from matplotlib==3.9.3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/lo/anaconda3/lib/python3.13/site-packages (from matplotlib==3.9.3) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/lo/anaconda3/lib/python3.13/site-packages (from matplotlib==3.9.3) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/lo/anaconda3/lib/python3.13/site-packages (from matplotlib==3.9.3) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in /home/lo/anaconda3/lib/python3.13/site-packages (from matplotlib==3.9.3) (25.0)
# Requirement already satisfied: pillow>=8 in /home/lo/anaconda3/lib/python3.13/site-packages (from matplotlib==3.9.3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/lo/anaconda3/lib/python3.13/site-packages (from matplotlib==3.9.3) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/lo/anaconda3/lib/python3.13/site-packages (from matplotlib==3.9.3) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/lo/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib==3.9.3) (1.17.0)

# %% [markdown]
# Luego en nuestro programa importamos las dependencias y cargamos el dataset
