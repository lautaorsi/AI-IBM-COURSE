# %% [markdown]
# # Forward Propagation
#
# En este notebook vamos a hacer una función que dada una red neuronal (con sus respectivos pesos y capas) y un input procesa la información y retorna la predicción del modelo. <br> <br>
#
# ### SETUP

# %%
# !pip install numpy==1.26.4

import numpy as np

# %% [markdown]
# ## Creación de Red
#
# Antes de poder predecir resultados necesitamos tener una forma modularizada y rápida de crear redes neuronales, tomando como parametros la cantidad de capas, cantidad de nodos de salida, cantidad de nodos de entrada y cantidad de nodos por capa escondida. Luego, nuestra función va a asignar pesos al azar en cada conexión.

# %%
def initialize_network(num_inputs, num_hidden_layers, num_nodes_hidden, num_nodes_output):
    
    num_nodes_previous = num_inputs # number of nodes in the previous layer

    network = {}
    
    # loop through each layer and randomly initialize the weights and biases associated with each layer
    for layer in range(num_hidden_layers + 1):
        
        if layer == num_hidden_layers:
            layer_name = 'output' # name last layer in the network output
            num_nodes = num_nodes_output
        else:
            layer_name = 'layer_{}'.format(layer + 1) # otherwise give the layer a number
            num_nodes = num_nodes_hidden[layer] 
        
        # initialize weights and bias for each node
        network[layer_name] = {}
        for node in range(num_nodes):
            node_name = 'node_{}'.format(node+1)
            network[layer_name][node_name] = {
                'weights': np.around(np.random.uniform(size=num_nodes_previous), decimals=2),
                'bias': np.around(np.random.uniform(size=1), decimals=2),
            }
     
        num_nodes_previous = num_nodes

    return network # return the network

# %% [markdown]
# Notemos que esta función va a asignar pesos al azar en las aristas de la red, en este laboratorio no vamos a trabajar la backpropagation y por lo tanto no vamos a optimizarlo, pero sirve para obtener una red neuronal funcional.
#
# ## Procesamiento de Datos (Forward Propagation)
#
# Teniendo la red creemos una función que recibe un input y se lo da a la red neuronal para su procesamiento.

# %%
def compute_weighted_sum(inputs, weights, bias):
    return np.sum(inputs * weights) + bias

def node_activation(weighted_sum):
    return 1.0 / (1.0 + np.exp(-1 * weighted_sum))

# %%
def forward_propagate(network, inputs):
    
    layer_inputs = list(inputs) # start with the input layer as the input to the first hidden layer
    
    for layer in network:
        
        layer_data = network[layer]
        
        layer_outputs = [] 
        for layer_node in layer_data:
        
            node_data = layer_data[layer_node]
        
            # compute the weighted sum and the output of each node at the same time 
            node_output = node_activation(compute_weighted_sum(layer_inputs, node_data['weights'], node_data['bias']))
            layer_outputs.append(np.around(node_output[0], decimals=4))
            
        if layer != 'output':
            print('The outputs of the nodes in hidden layer number {} is {}'.format(layer.split('_')[1], layer_outputs))
    
        layer_inputs = layer_outputs # set the output of this layer to be the input to next layer

    network_predictions = layer_outputs
    return network_predictions

# %%
network = initialize_network(3,5,[5,3,5,3,5],3)
inputs = np.around(np.random.uniform(size=3), decimals=2)

forward_propagate(network,inputs)
# Out:
# The outputs of the nodes in hidden layer number 1 is [np.float64(0.6993), np.float64(0.7801), np.float64(0.7453), np.float64(0.7048), np.float64(0.6664)]
# The outputs of the nodes in hidden layer number 2 is [np.float64(0.776), np.float64(0.9211), np.float64(0.8826)]
# The outputs of the nodes in hidden layer number 3 is [np.float64(0.9183), np.float64(0.9041), np.float64(0.9578), np.float64(0.7317), np.float64(0.7607)]
# The outputs of the nodes in hidden layer number 4 is [np.float64(0.827), np.float64(0.9633), np.float64(0.7363)]
# The outputs of the nodes in hidden layer number 5 is [np.float64(0.7328), np.float64(0.7904), np.float64(0.8715), np.float64(0.7007), np.float64(0.9002)]
# [np.float64(0.83), np.float64(0.9053), np.float64(0.9587)]

# %% [markdown]
# Con esto armamos la base de la Red Neuronal y vamos a ver mas adelante como acomodar los pesos para obtener modelos significativos.
